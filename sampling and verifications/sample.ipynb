# %% [markdown]
# ### Sample 10% of videos from outputs folder

# %%
import os
import random
import math

base_dir = '/Users/eveyhuang/Documents/NICO/gemini_code/outputs'

# Collect all JSON files and map them to their video file names
video_file_map = {}
for root, dirs, files in os.walk(base_dir):
    for file in files:
        if file.endswith('.json') and not file.startswith('all_') and not file.startswith('verbal_'):
            video_name = file.replace('.json', '')
            full_path = os.path.join(root, file)
            if video_name not in video_file_map:
                video_file_map[video_name] = []
            video_file_map[video_name].append(full_path)

# Get all unique video names
all_video_names = list(video_file_map.keys())
print(f"Total unique video names found: {len(all_video_names)}")
n_sample = max(1, math.ceil(0.1 * len(all_video_names)))  # At least 1

print(f"Number of videos to sample: {n_sample}")
# Randomly sample 10% of video names
random.seed(42)  # For reproducibility
sampled_video_names = random.sample(all_video_names, n_sample)

# Get all file paths for the sampled videos
sampled_file_paths = []
for name in sampled_video_names:
    sampled_file_paths.extend(video_file_map[name])

# Print or save the sampled file paths
print("Sampled JSON files for verification:")
for path in sampled_file_paths:
    print(path)

# Optionally, save to a text file
with open('sampled_json_files.txt', 'w') as f:
    for path in sampled_file_paths:
        f.write(path + '\n')
# Out:
# Total unique video names found: 781
# Number of videos to sample: 79
# Sampled JSON files for verification:
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MND/output_2021_04_22_MND_S6/Breakout_Room_4_Part_2_2021_04_22_13_14_53/Breakout_Room_4_Part_2_2021_04_22_13_14_53_chunk6.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_21_ABI_S5/bot5p3_Room_5_Zoom_Meeting_5_21_2021_10_59_19_AM/bot5p3_Room_5_Zoom_Meeting_5_21_2021_10_59_19_AM_chunk3.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_20_ABI_S4/bot2p2_Zoom_Meeting_2021_05_20_12_37_07/bot2p2_Zoom_Meeting_2021_05_20_12_37_07_chunk3.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MZT/output_2021_10_01_MZT_S1/B1.2_Zoom_Meeting_Room_1_2021_10_01_11_07_45/B1.2_Zoom_Meeting_Room_1_2021_10_01_11_07_45.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021SLU/output_2021_06_10_SLU_S5/botB2_2021_06_10_12_35_06/botB2_2021_06_10_12_35_06_chunk2.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021SLU/output_2021_06_10_SLU_S3/bot3p2_Room_3_Zoom_Meeting_2021_06_10_12_36_45/bot3p2_Room_3_Zoom_Meeting_2021_06_10_12_36_45_chunk2.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021SLU/output_2021_06_11_SLU_S6/Zoom_Meeting_Room_6_2021_06_11_10_58_05/Zoom_Meeting_Room_6_2021_06_11_10_58_05_chunk1.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_20_ABI_S6/bot4_Breakout_Room_4_2021_05_20_12_33_49/bot4_Breakout_Room_4_2021_05_20_12_33_49_chunk1.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MZT/output_2021_10_01_MZT_S7/B1_Zoom_Meeting_Room_1_2021_10_01_13_12_04/B1_Zoom_Meeting_Room_1_2021_10_01_13_12_04_chunk3.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_21_ABI_S12/bot5p4_Zoom_Meeting_5_21_2021_1_12_46_PM/bot5p4_Zoom_Meeting_5_21_2021_1_12_46_PM_chunk3.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MZT/output_2021_10_01_MZT_S3/B3_2021_10_01_11_04_47/B3_2021_10_01_11_04_47_chunk4.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MZT/output_2021_10_01_MZT_S1/B1.1_Zoom_Meeting_Room_1_2021_10_01_11_04_18/B1.1_Zoom_Meeting_Room_1_2021_10_01_11_04_18.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MND/output_2021_04_23_MND_S7/Breakout_Room_4_Session_2_2021_04_23_11_15_47/Breakout_Room_4_Session_2_2021_04_23_11_15_47_chunk7.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_21_ABI_S14/botB1_2021_05_21_13_09_38/botB1_2021_05_21_13_09_38_chunk2.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MND/output_2021_04_23_MND_S2/bot1_2021_04_23_11_15_35/bot1_2021_04_23_11_15_35_chunk6.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2020NES/output_2020_11_05_NES_S3/3_Sorbents_Zoom_Meeting_2020_11_05_12_20_44/3_Sorbents_Zoom_Meeting_2020_11_05_12_20_44_chunk3.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_20_ABI_S3/bot1_2021_05_20_12_35_38/bot1_2021_05_20_12_35_38_chunk2.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_20_ABI_S3/bot1_2021_05_20_12_35_38/bot1_2021_05_20_12_35_38_chunk4.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_21_ABI_S15/botB3_2021_05_21_13_09_30/botB3_2021_05_21_13_09_30_chunk3.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021SLU/output_2021_06_11_SLU_S1/bot1_2021_06_11_10_57_56/bot1_2021_06_11_10_57_56_chunk8.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021SLU/output_2021_06_10_SLU_S4/bot4_2021_06_10_12_35_05/bot4_2021_06_10_12_35_05_chunk3.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MND/output_2021_04_23_MND_S8/Zoom_Meeting_Room_6_2021_04_23_11_22_11/Zoom_Meeting_Room_6_2021_04_23_11_22_11_chunk4.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MND/output_2021_04_23_MND_S14/botB2_2021_04_23_13_14_21/botB2_2021_04_23_13_14_21_chunk2.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_20_ABI_S3/bot1_2021_05_20_12_35_38/bot1_2021_05_20_12_35_38_chunk6.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MND/output_2021_04_22_MND_S5/botB2_2021_04_22_13_02_15/botB2_2021_04_22_13_02_15_chunk6.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021SLU/output_2021_06_11_SLU_S10/bot3p2_Room_3_Zoom_Meeting_2021_06_11_13_03_36/bot3p2_Room_3_Zoom_Meeting_2021_06_11_13_03_36_chunk3.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MZT/output_2021_09_30_MZT_S4/B4_2021_09_30_13_05_04/B4_2021_09_30_13_05_04_chunk1.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MND/output_2021_04_22_MND_S1/Bot1_2021_04_22_13_00_44/Bot1_2021_04_22_13_00_44_chunk1.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MZT/output_2021_10_01_MZT_S2/B2_Zoom_Meeting_Room_2_2021_10_01_11_04_45/B2_Zoom_Meeting_Room_2_2021_10_01_11_04_45_chunk7.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2020NES/output_2020_11_05_NES_S3/3_Sorbents_Zoom_Meeting_2020_11_05_12_20_44/3_Sorbents_Zoom_Meeting_2020_11_05_12_20_44_chunk4.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021SLU/output_2021_06_11_SLU_S1/bot1_2021_06_11_10_57_56/bot1_2021_06_11_10_57_56_chunk2.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2020NES/output_2020_11_06_NES_S9/2020_11_06_12_09_40/2020_11_06_12_09_40_chunk1.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MND/output_2021_04_23_MND_S2/bot1_2021_04_23_11_15_35/bot1_2021_04_23_11_15_35_chunk7.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021SLU/output_2021_06_10_SLU_S5/botB2_2021_06_10_12_35_06/botB2_2021_06_10_12_35_06_chunk8.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_21_ABI_S1/Bot_4_Breakout_Session_2_2021_05_21_10_58_43/Bot_4_Breakout_Session_2_2021_05_21_10_58_43_chunk6.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MZT/output_2021_10_01_MZT_S11/B5_2021_10_01_13_12_03/B5_2021_10_01_13_12_03_chunk2.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_20_ABI_S8/botB2_2021_05_20_12_34_37/botB2_2021_05_20_12_34_37_chunk8.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MZT/output_2021_10_01_MZT_S2/B2_Zoom_Meeting_Room_2_2021_10_01_11_04_45/B2_Zoom_Meeting_Room_2_2021_10_01_11_04_45_chunk2.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021SLU/output_2021_06_10_SLU_S1/bot1_2021_06_10_12_34_46/bot1_2021_06_10_12_34_46_chunk5.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_20_ABI_S8/botB2_2021_05_20_12_34_37/botB2_2021_05_20_12_34_37_chunk3.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021SLU/output_2021_06_11_SLU_S1/bot1_2021_06_11_10_57_56/bot1_2021_06_11_10_57_56_chunk6.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021SLU/output_2021_06_10_SLU_S1/bot1_2021_06_10_12_34_46/bot1_2021_06_10_12_34_46_chunk6.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_21_ABI_S15/botB3_2021_05_21_13_09_30/botB3_2021_05_21_13_09_30_chunk1.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2020NES/output_2020_11_05_NES_S6/6_Theory_and_Expt_Zoom_Meeting_2020_11_05_10_28_39/6_Theory_and_Expt_Zoom_Meeting_2020_11_05_10_28_39_chunk1.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_21_ABI_S12/bot5p1_Zoom_Meeting_5_21_2021_1_08_57_PM/bot5p1_Zoom_Meeting_5_21_2021_1_08_57_PM.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021SLU/output_2021_06_11_SLU_S4/bot4_2021_06_11_10_58_21/bot4_2021_06_11_10_58_21_chunk1.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021SLU/output_2021_06_11_SLU_S3/bot3p2_Room_3_Zoom_Meeting_2021_06_11_10_59_57/bot3p2_Room_3_Zoom_Meeting_2021_06_11_10_59_57_chunk8.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MND/output_2021_04_23_MND_S3/bot2_Zoom_Meeting_Room_2_2021_04_23_11_18_13/bot2_Zoom_Meeting_Room_2_2021_04_23_11_18_13_chunk6.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021SLU/output_2021_06_10_SLU_S2/bot2p2_Zoom_Meeting_Room_2_2021_06_10_12_37_25/bot2p2_Zoom_Meeting_Room_2_2021_06_10_12_37_25_chunk6.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_21_ABI_S9/bot1_2021_05_21_13_08_36/bot1_2021_05_21_13_08_36_chunk1.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MZT/output_2021_10_01_MZT_S9/B3_2021_10_01_13_12_21/B3_2021_10_01_13_12_21_chunk4.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2020NES/output_2020_11_06_NES_S7/1_beyond_co2_Zoom_Meeting_2020_11_06_12_11_55/1_beyond_co2_Zoom_Meeting_2020_11_06_12_11_55_chunk5.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MND/output_2021_04_23_MND_S6/botB2_2021_04_23_11_17_00/botB2_2021_04_23_11_17_00_chunk5.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_20_ABI_S7/botB1_2021_05_20_12_34_57/botB1_2021_05_20_12_34_57_chunk5.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2020NES/output_2020_11_05_NES_S6/6_Theory_and_Expt_Zoom_Meeting_2020_11_05_10_09_14/6_Theory_and_Expt_Zoom_Meeting_2020_11_05_10_09_14_chunk2.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_21_ABI_S13/bot6p3_Zoom_Meeting_Room_6_2021_05_21_13_12_29/bot6p3_Zoom_Meeting_Room_6_2021_05_21_13_12_29_chunk3.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MND/output_2021_04_23_MND_S9/Bot_5_Zoom_Meeting_4_23_2021_1_13_23_PM/Bot_5_Zoom_Meeting_4_23_2021_1_13_23_PM.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021SLU/output_2021_06_11_SLU_S13/Zoom_Meeting_6_11_2021_1_02_20_PM/Zoom_Meeting_6_11_2021_1_02_20_PM_chunk3.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MND/output_2021_04_23_MND_S4/bot3_Zoom_Meeting_2021_04_23_11_16_26/bot3_Zoom_Meeting_2021_04_23_11_16_26_chunk3.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MND/output_2021_04_23_MND_S13/botB1_2021_04_23_13_14_18/botB1_2021_04_23_13_14_18_chunk4.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2020NES/output_2020_11_06_NES_S10/4_frontiers_in_echem_Zoom_Meeting_2020_11_06_12_52_00/4_frontiers_in_echem_Zoom_Meeting_2020_11_06_12_52_00_chunk3.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2020NES/output_2020_11_06_NES_S10/4_frontiers_in_echem_Zoom_Meeting_2020_11_06_12_15_06/4_frontiers_in_echem_Zoom_Meeting_2020_11_06_12_52_00_chunk3.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MND/output_2021_04_23_MND_S12/bot3_Room_3_Zoom_Meeting_2021_04_23_13_13_23/bot3_Room_3_Zoom_Meeting_2021_04_23_13_13_23_chunk1.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_21_ABI_S16/Breakout_Room_4_Session_3_2021_04_23_13_13_06/Breakout_Room_4_Session_3_2021_04_23_13_13_06_chunk1.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MND/output_2021_04_23_MND_S15/Breakout_Room_4_Session_3_2021_04_23_13_13_06/Breakout_Room_4_Session_3_2021_04_23_13_13_06_chunk1.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MZT/output_2021_09_30_MZT_S2/B2_Zoom_Meeting_Room_2_2021_09_30_12_55_56/B2_Zoom_Meeting_Room_2_2021_09_30_12_55_56_chunk1.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_21_ABI_S7/botB1_2021_05_21_10_58_58/botB1_2021_05_21_10_58_58_chunk4.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_21_ABI_S9/bot1_2021_05_21_13_08_36/bot1_2021_05_21_13_08_36_chunk3.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MZT/output_2021_09_30_MZT_S7/MZT_1_2/MZT_1_2_chunk5.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021SLU/output_2021_06_11_SLU_S6/Zoom_Meeting_Room_6_2021_06_11_10_58_05/Zoom_Meeting_Room_6_2021_06_11_10_58_05_chunk5.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021SLU/output_2021_06_11_SLU_S13/Zoom_Meeting_6_11_2021_1_02_20_PM/Zoom_Meeting_6_11_2021_1_02_20_PM_chunk8.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_21_ABI_S13/bot6p3_Zoom_Meeting_Room_6_2021_05_21_13_12_29/bot6p3_Zoom_Meeting_Room_6_2021_05_21_13_12_29_chunk1.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_21_ABI_S12/bot5p4_Zoom_Meeting_5_21_2021_1_12_46_PM/bot5p4_Zoom_Meeting_5_21_2021_1_12_46_PM_chunk1.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2020NES/output_2020_11_06_NES_S9/2020_11_06_12_09_40/2020_11_06_12_09_40_chunk8.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MND/output_2021_04_22_MND_S6/Breakout_Room_4_Part_2_2021_04_22_13_14_53/Breakout_Room_4_Part_2_2021_04_22_13_14_53_chunk5.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2020NES/output_2020_11_06_NES_S10/4_frontiers_in_echem_Zoom_Meeting_2020_11_06_12_23_32/4_frontiers_in_echem_Zoom_Meeting_2020_11_06_12_23_32_chunk2.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021ABI/output_2021_05_20_ABI_S8/botB2_2021_05_20_12_34_37/botB2_2021_05_20_12_34_37_chunk1.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2020NES/output_2020_11_06_NES_S11/5_what_to_do_with_captured_carbon_Zoom_Meeting_2020_11_06_12_16_53/5_what_to_do_with_captured_carbon_Zoom_Meeting_2020_11_06_12_16_53_chunk5.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021SLU/output_2021_06_11_SLU_S4/bot4_2021_06_11_10_58_21/bot4_2021_06_11_10_58_21_chunk4.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021SLU/output_2021_06_11_SLU_S11/bot4_2021_06_11_13_02_17/bot4_2021_06_11_13_02_17_chunk3.json
# /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MZT/output_2021_10_01_MZT_S3/B3_2021_10_01_11_04_47/B3_2021_10_01_11_04_47_chunk10.json

# %%
import json
sampled_dict = {}

with open('sampled_json_files.txt', 'r') as f:
    file_paths = [line.strip() for line in f if line.strip()]

def extract_key_and_subkey(path):
    # Get the part after '/outputs/'
    rest = path.split('/outputs/')[1]
    parts = rest.split(os.sep)
    key = os.path.join(parts[0], parts[1])
    sub_key = os.path.join(*parts[2:])  # Join everything after the key
    return key, sub_key

for path in file_paths:
    # Extract key after 'output_'
    try:
        key, sub_key = extract_key_and_subkey(path)
        
    except Exception as e:
        print(f"Skipping {path}: {e}")
        continue

    # Load JSON and sample a value
    try:
        with open(path, 'r') as jf:
            data = json.load(jf)
        if isinstance(data, list) and data:
            sampled_value = random.choice(data)
        elif isinstance(data, dict) and data:
            filtered = [ann for ann in data["meeting_annotations"] if ann["speaking duration"] > 10]
            if filtered:
                sampled_value = random.choice(filtered)
            else:
                # Fallback to any annotation if none meet the criteria
                sampled_value = None
        else:
            sampled_value = data
    except Exception as e:
        print(f"Error reading {path}: {e}")
        continue

    if key not in sampled_dict:
        sampled_dict[key] = {}
    sampled_dict[key][sub_key] = sampled_value

# Save to a new JSON file
with open('sampled_verification.json', 'w') as out_f:
    json.dump(sampled_dict, out_f, indent=2)
# Out:
# Error reading /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2021MZT/output_2021_10_01_MZT_S1/B1.1_Zoom_Meeting_Room_1_2021_10_01_11_04_18/B1.1_Zoom_Meeting_Room_1_2021_10_01_11_04_18.json: 'speaking duration'
# Error reading /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2020NES/output_2020_11_05_NES_S3/3_Sorbents_Zoom_Meeting_2020_11_05_12_20_44/3_Sorbents_Zoom_Meeting_2020_11_05_12_20_44_chunk3.json: 'speaking duration'
# Error reading /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2020NES/output_2020_11_05_NES_S3/3_Sorbents_Zoom_Meeting_2020_11_05_12_20_44/3_Sorbents_Zoom_Meeting_2020_11_05_12_20_44_chunk4.json: 'speaking duration'
# Error reading /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2020NES/output_2020_11_05_NES_S6/6_Theory_and_Expt_Zoom_Meeting_2020_11_05_10_28_39/6_Theory_and_Expt_Zoom_Meeting_2020_11_05_10_28_39_chunk1.json: 'speaking duration'
# Error reading /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2020NES/output_2020_11_06_NES_S7/1_beyond_co2_Zoom_Meeting_2020_11_06_12_11_55/1_beyond_co2_Zoom_Meeting_2020_11_06_12_11_55_chunk5.json: 'speaking duration'
# Error reading /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2020NES/output_2020_11_05_NES_S6/6_Theory_and_Expt_Zoom_Meeting_2020_11_05_10_09_14/6_Theory_and_Expt_Zoom_Meeting_2020_11_05_10_09_14_chunk2.json: 'speaking duration'
# Error reading /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2020NES/output_2020_11_06_NES_S10/4_frontiers_in_echem_Zoom_Meeting_2020_11_06_12_15_06/4_frontiers_in_echem_Zoom_Meeting_2020_11_06_12_52_00_chunk3.json: 'speaking duration'
# Error reading /Users/eveyhuang/Documents/NICO/gemini_code/outputs/2020NES/output_2020_11_06_NES_S11/5_what_to_do_with_captured_carbon_Zoom_Meeting_2020_11_06_12_16_53/5_what_to_do_with_captured_carbon_Zoom_Meeting_2020_11_06_12_16_53_chunk5.json: 'speaking duration'
